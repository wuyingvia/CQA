# %% [markdown]
# 画每个不确定性量化的展示图，暂定 pems04 graphwavenet
# date:20221102

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/home/wuying/CODE/mymodel/2022/CQA/configuration/PEMS04.conf').values

# %%
def remove_moving_window(speed):

    batch_num, n_pred, n_node = speed.shape
    select_idx = np.arange(0, batch_num, n_pred)
    speed = speed[select_idx, :, :]

    speed = np.reshape(speed, (-1, n_node))
    print(speed.shape)

    return speed

# %%
# HA 
# monday is 0 while sunday is 6

groundtruth = np.load('/home/wuying/CODE/mymodel/2022/CQA/results/figures/save/pred_HA_PEMS04/_groundtruth.npy')
lower = np.load('/home/wuying/CODE/mymodel/2022/CQA/results/figures/save/pred_HA_PEMS04/_pred_lower.npy')
upper = np.load('/home/wuying/CODE/mymodel/2022/CQA/results/figures/save/pred_HA_PEMS04/_pred_upper.npy')


ha_groundtruth = groundtruth.reshape([-1,307])[1200:]
ha_lower = lower.reshape([-1,307])[1200:]
ha_upper = upper.reshape([-1,307])[1200:]
print(ha_groundtruth.shape)
# Out:
# (816, 307)

# %%
# bayesain

groundtruth = np.load('/home/wuying/CODE/mymodel/2022/CQA/results/figures/save/pred_PEMS04_GraphWaveNet_bayesian_2211171007/GraphWaveNet_groundtruth.npy')
lower = np.load('/home/wuying/CODE/mymodel/2022/CQA/results/figures/save/pred_PEMS04_GraphWaveNet_bayesian_2211171007/GraphWaveNet_lower.npy')
upper = np.load('/home/wuying/CODE/mymodel/2022/CQA/results/figures/save/pred_PEMS04_GraphWaveNet_bayesian_2211171007/GraphWaveNet_groundtruth.npy')

print(groundtruth.shape)

bayesian_groundtruth = remove_moving_window(groundtruth)[-3396:,]
bayesian_lower = remove_moving_window(lower)[-3396:,]
bayesian_upper = remove_moving_window(upper)[-3396:,]
print(bayesian_upper.shape)
# Out:
# (8485, 12, 307)
# (8496, 307)
# (8496, 307)
# (8496, 307)
# (3396, 307)

# %%
# dropout

groundtruth = np.load('/home/wuying/CODE/mymodel/2022/CQA/results/figures/save/pred_PEMS04_GraphWaveNet_dropout_2211040932/GraphWaveNet_groundtruth.npy')
lower = np.load('/home/wuying/CODE/mymodel/2022/CQA/results/figures/save/pred_PEMS04_GraphWaveNet_dropout_2211040932/GraphWaveNet_lower.npy')
upper = np.load('/home/wuying/CODE/mymodel/2022/CQA/results/figures/save/pred_PEMS04_GraphWaveNet_dropout_2211040932/GraphWaveNet_upper.npy')

print(groundtruth.shape)

dropout_groundtruth = remove_moving_window(groundtruth)[-3396:,]
dropout_lower = remove_moving_window(lower)[-3396:,]
dropout_upper = remove_moving_window(upper)[-3396:,]
# Out:
# (8485, 12, 307)
# (8496, 307)
# (8496, 307)
# (8496, 307)

# %%
#  conformal

groundtruth = np.load('/home/wuying/CODE/mymodel/2022/CQA/results/figures/save/pred_PEMS04_GraphWaveNet_conformal_2211032011/GraphWaveNet_groundtruth.npy')
lower = np.load('/home/wuying/CODE/mymodel/2022/CQA/results/figures/save/pred_PEMS04_GraphWaveNet_conformal_2211032011/GraphWaveNet_lower.npy')
upper = np.load('/home/wuying/CODE/mymodel/2022/CQA/results/figures/save/pred_PEMS04_GraphWaveNet_conformal_2211032011/GraphWaveNet_upper.npy')

print(groundtruth.shape)

conformal_groundtruth = remove_moving_window(groundtruth)[-3396:,]
conformal_lower = remove_moving_window(lower)[-3396:,]
conformal_upper = remove_moving_window(upper)[-3396:,]
# Out:
# (3388, 12, 307)
# (3396, 307)
# (3396, 307)
# (3396, 307)

# %%
#  quantile

groundtruth = np.load('/home/wuying/CODE/mymodel/2022/CQA/results/figures/save/pred_PEMS04_GraphWaveNet_quantile_2211032019/GraphWaveNet_groundtruth.npy')
lower = np.load('/home/wuying/CODE/mymodel/2022/CQA/results/figures/save/pred_PEMS04_GraphWaveNet_quantile_2211032019/GraphWaveNet_pred_lower.npy')
upper = np.load('/home/wuying/CODE/mymodel/2022/CQA/results/figures/save/pred_PEMS04_GraphWaveNet_quantile_2211032019/GraphWaveNet_pred_upper.npy')

print(groundtruth.shape)

quantile_groundtruth = remove_moving_window(groundtruth)[-3396:,]
quantile_lower = remove_moving_window(lower)[-3396:,]
quantile_upper = remove_moving_window(upper)[-3396:,]
# Out:
# (3388, 12, 307)
# (3396, 307)
# (3396, 307)
# (3396, 307)

# %%
#  quantile conformal

groundtruth = np.load('/home/wuying/CODE/mymodel/2022/CQA/results/figures/save/pred_PEMS04_GraphWaveNet_quantile_conformal_2211032010/GraphWaveNet_groundtruth.npy')
lower = np.load('/home/wuying/CODE/mymodel/2022/CQA/results/figures/save/pred_PEMS04_GraphWaveNet_quantile_conformal_2211032010/GraphWaveNet_lower.npy')
upper = np.load('/home/wuying/CODE/mymodel/2022/CQA/results/figures/save/pred_PEMS04_GraphWaveNet_quantile_conformal_2211032010/GraphWaveNet_upper.npy')

print(groundtruth.shape)

quantile_conformal_groundtruth = remove_moving_window(groundtruth)[-3396:,]
quantile_conformal_lower = remove_moving_window(lower)[-3396:,]
quantile_conformal_upper = remove_moving_window(upper)[-3396:,]
# Out:
# (3388, 12, 307)
# (3396, 307)
# (3396, 307)
# (3396, 307)

# %%
#  adaptive

groundtruth = np.load('/home/wuying/CODE/mymodel/2022/CQA/results/figures/save/pred_PEMS04_GraphWaveNet_adaptive_2211240934/GraphWaveNet_groundtruth.npy')
lower = np.load('/home/wuying/CODE/mymodel/2022/CQA/results/figures/save/pred_PEMS04_GraphWaveNet_adaptive_2211240934/GraphWaveNet_pred_lower.npy')
upper = np.load('/home/wuying/CODE/mymodel/2022/CQA/results/figures/save/pred_PEMS04_GraphWaveNet_adaptive_2211240934/GraphWaveNet_pred_upper.npy')

adaptive_groundtruth = remove_moving_window(groundtruth)[-3396:,]
adaptive_lower = remove_moving_window(lower)[-3396:,]
adaptive_upper = remove_moving_window(upper)[-3396:,]
print(adaptive_groundtruth.shape)
# Out:
# (3396, 307)
# (3396, 307)
# (3396, 307)
# (3396, 307)

# %%
# 时间index
index = pd.date_range(start = '2018-01-01',end='2018-03-01', freq='5min')[:-1]
index.shape

# bayesian dropout
index_t = index[-3396:]

# q qc 
# index_t = index[-3396:]

# start from 18:00

index_t[156]
# Out:
# Timestamp('2018-02-17 18:00:00', freq='5T')

# %%
np.where(np.sum(groundtruth < 5, axis=0) == 0)
# Out:
# (array([ 0,  0,  0, ..., 11, 11, 11]),
#  array([  0,   1,   2, ..., 300, 301, 302]))

# %%
plot_day_len = 1
plot_start =  156 
plot_sensor_id = 120

fontsize = 14
x_ticks_pos = np.linspace(0, 288, 5)
x_tick_labels = ['18:00','00:00', '06:00', '12:00','18:00']

fig, ax = plt.subplots(figsize=(10, 6), dpi=150)
plt.cla()

x_range = np.arange(plot_day_len * 288)

# plot ground truth
plot_groundtruth = adaptive_groundtruth[plot_start : plot_day_len*288 + plot_start, plot_sensor_id]
ax.plot(plot_groundtruth, '.', color = 'black', label='GroundTruth')

# find outliner
out_idx = np.where(
    (plot_groundtruth < adaptive_lower[plot_start : plot_day_len*288 + plot_start, plot_sensor_id] ) | (
    adaptive_upper[plot_start : plot_day_len*288 + plot_start, plot_sensor_id] < plot_groundtruth)
    )
ax.plot(x_range[out_idx], plot_groundtruth[out_idx],'.', color = 'red', label='GroundTruth')

ax.plot(adaptive_lower[plot_start : plot_day_len*288 + plot_start, plot_sensor_id],linestyle = '-', color = 'grey')
ax.plot(adaptive_upper[plot_start : plot_day_len*288 + plot_start, plot_sensor_id],linestyle = '-', color = 'grey')
ax.fill_between(
    x_range,
    adaptive_lower[plot_start : plot_day_len*288 + plot_start, plot_sensor_id],
    adaptive_upper[plot_start : plot_day_len*288 + plot_start, plot_sensor_id],
    facecolor = 'grey', alpha = 0.5
)



ax.set_xticks(x_ticks_pos)
ax.set_xticklabels(x_tick_labels)

ax.set_xlabel('Time', fontsize=fontsize)
ax.set_ylabel('Flow', fontsize=fontsize)

plt.xticks(fontsize = fontsize)
plt.yticks(fontsize = fontsize)

ax.grid()

# ax.legend(fontsize=fontsize)

fig.show()

# %% [markdown]
# visualization of prediction interval

# %%
plot_day_len = 1
plot_start =  156 
plot_sensor_id = 66


fontsize = 14
x_ticks_pos = np.linspace(0, 288, 5)
x_tick_labels = ['18:00','00:00', '06:00', '12:00','18:00']

fig, axs = plt.subplots(2, 4, sharex=True, sharey=True, figsize=(20, 10))
plt.cla()
plt.subplots_adjust(wspace=0.18)
plt.subplots_adjust(hspace=0.2)

x_range = np.arange(plot_day_len * 288)


handle_ground = []
handle_outline = []
handle_interval = []


def plot_subfig(ax, groundtruth, lower, upper, name):

    # plot ground truth
    plot_groundtruth = groundtruth[plot_start : plot_day_len*288 + plot_start, plot_sensor_id]
    handle_ground = ax.plot(plot_groundtruth, '.', color = 'black', label='GroundTruth')

    # find outliner
    out_idx = np.where(
        (plot_groundtruth < lower[plot_start : plot_day_len*288 + plot_start, plot_sensor_id] ) | (
        upper[plot_start : plot_day_len*288 + plot_start, plot_sensor_id] < plot_groundtruth)
        )
    handle_outline = ax.plot(x_range[out_idx], plot_groundtruth[out_idx],'.', color = 'red', label='GroundTruth')

    ax.plot(lower[plot_start : plot_day_len*288 + plot_start, plot_sensor_id],linestyle = '-', color = 'grey')
    ax.plot(upper[plot_start : plot_day_len*288 + plot_start, plot_sensor_id],linestyle = '-', color = 'grey')
    handle_interval = ax.fill_between(
        x_range,
        lower[plot_start : plot_day_len*288 + plot_start, plot_sensor_id],
        upper[plot_start : plot_day_len*288 + plot_start, plot_sensor_id],
        facecolor = 'grey', alpha = 0.5
    )

    ax.set_xlim([x_range[0], x_range[-1]])
    ax.set_xticks(x_ticks_pos)
    ax.set_xticklabels(x_tick_labels)

    ax.set_title('{:s} \n Coverage:{:.2f}%  Interval:{:.2f}'.format(
        name, 
        100 - len(out_idx[0])/plot_day_len/288 * 100, 
        np.mean(
            upper[plot_start : plot_day_len*288 + plot_start, plot_sensor_id] - 
            lower[plot_start : plot_day_len*288 + plot_start, plot_sensor_id]
        )), fontsize=fontsize)
    ax.tick_params(labelsize=fontsize, colors='k')

    ax.grid()

plot_subfig(axs[0,0], dropout_groundtruth,  ha_upper, ha_lower,'ha-w')
plot_subfig(axs[0,1], dropout_groundtruth, dropout_lower * (dropout_lower>0) , dropout_upper, 'dropout')
plot_subfig(axs[0,2], bayesian_groundtruth, bayesian_lower, bayesian_upper, 'bayesian')
plot_subfig(axs[0,3], conformal_groundtruth, conformal_lower, conformal_upper, 'conformal')
plot_subfig(axs[1,0], quantile_groundtruth, quantile_lower, quantile_upper, 'quantile')
plot_subfig(axs[1,1], quantile_groundtruth, quantile_conformal_lower, quantile_conformal_upper, 'quantile conformal')
plot_subfig(axs[1,2], adaptive_groundtruth, adaptive_lower, adaptive_upper,  'adaptive')



[axs[1,i].set_xlabel('Time', fontsize=fontsize) for i in range(4)]
[axs[i,0].set_ylabel('Flow', fontsize=fontsize) for i in range(2)]

plt.delaxes(axs[1,3])

fig.legend([handle_ground, handle_outline, handle_interval], 
            labels=['groundtruth', 'out of coverage', 'interval'],
           loc='center',  bbox_to_anchor=(0.72, 0.25), fontsize=fontsize+4, 
framealpha=0.5, borderaxespad=0,  ncol=1)
# ax.grid()

# ax.legend(fontsize=fontsize)

# fig.show()

plt.savefig('interval.pdf', bbox_inches='tight')
# Out:
# /home/wuying/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:78: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.

# %% [markdown]
# ### coverage and interval by nodes

# %%
ontsize = 14
x_ticks_pos = np.linspace(0, 288, 5)


# fig, axs = plt.subplots(2, 1, sharex=True, figsize=(16, 7))
# plt.cla()
# # plt.subplots_adjust(wspace=0.18)
# plt.subplots_adjust(hspace=0.1)

fig = plt.figure(figsize=(24, 10))

gs = fig.add_gridspec(2, 3, width_ratios=(14,1.5,1.5), height_ratios=(1,1), wspace=0.05)

def plot_node_coverage_interval(axs, groundtruth, lower, upper, name):
    
    node_interval = np.mean(upper - lower, axis=0)
    is_covered = ((lower <= groundtruth) & (upper >= groundtruth))
    node_coverage = np.sum(is_covered, axis=0) / groundtruth.shape[0]*100

    if name == 'quantile conformal':
        axs[0].plot(node_coverage, '.', label=name)
        axs[1].plot(node_interval, '.')
    elif name == 'adaptive':
        axs[0].plot(node_coverage, '^', label=name)
        axs[1].plot(node_interval, '^')
    else:
        pass
    return node_coverage, node_interval


axs_cv = fig.add_subplot(gs[0,0])
axs_it = fig.add_subplot(gs[1,0])


qc_cv, qc_it = plot_node_coverage_interval([axs_cv, axs_it], quantile_conformal_groundtruth, quantile_conformal_lower, quantile_conformal_upper, 'quantile conformal')
ada_cv, ada_it = plot_node_coverage_interval([axs_cv, axs_it], adaptive_groundtruth, adaptive_lower, adaptive_upper, 'adaptive')

axs_cv.set_ylabel('(a) Coverage (%)', fontsize = fontsize)
axs_cv.tick_params(labelsize=fontsize)

axs_it.set_ylabel('(b) Interval', fontsize = fontsize)
axs_it.set_xlabel('Node No.', fontsize = fontsize)
axs_it.tick_params(labelsize=fontsize)
fig.subplots_adjust(top=0.8)


axs_cv_1 = fig.add_subplot(gs[0,1], sharey=axs_cv)
axs_cv_2 = fig.add_subplot(gs[0,2], sharey=axs_cv, sharex=axs_cv_1)

bins = np.arange(50, 100, 1)
axs_cv_1.hist(qc_cv, bins=bins, color=plt.cm.tab10(0), orientation='horizontal')
axs_cv_2.hist(ada_cv, bins=bins, color=plt.cm.tab10(1), orientation='horizontal')

axs_it_1 = fig.add_subplot(gs[1,1], sharey=axs_it)
axs_it_2 = fig.add_subplot(gs[1,2], sharey=axs_it, sharex=axs_it_1)

bins = np.arange(20, 210, 5)
axs_it_1.hist(qc_it, bins=bins, color=plt.cm.tab10(0), orientation='horizontal')
axs_it_2.hist(ada_it, bins=bins, color=plt.cm.tab10(1), orientation='horizontal')

for t in [axs_cv_1, axs_cv_2, axs_it_1, axs_it_2]:
    # t.axis('off')
    t.tick_params(axis='x', labelbottom=False)
    t.tick_params(axis='y', labelleft=False)

fig.legend(loc='center',  bbox_to_anchor=(0.5, 0.85), fontsize=fontsize+4, 
framealpha=0.5, borderaxespad=0,  ncol=5)
# fig.show()
fig.savefig('nodeqca_2.pdf', bbox_inches='tight')

# %%
# min coverage of node

upper = adaptive_groundtruth
lower = adaptive_lower
groundtruth = adaptive_upper

node_interval = np.mean(upper - lower, axis=0)
is_covered = ((lower <= groundtruth) & (upper >= groundtruth))
node_coverage = np.sum(is_covered, axis=0) / groundtruth.shape[0]*100

np.max(node_coverage)

# %%
# Out:
# 36.160188457008246
